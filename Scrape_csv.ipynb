# %%
from bs4 import BeautifulSoup
import requests
import sys

# %%
# desktop user-agent
USER_AGENT = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"

headers = {"user-agent": USER_AGENT}
r = requests.get("https://www.foodora.se/en/city/stockholm?r=1", headers=headers)

print("Status code: ", r.status_code)
# Out:
# Status code:  403

# %%
if r.status_code == 200:
    # resp = requests.get(URL, headers=headers)
    soup = BeautifulSoup(r.content, "html.parser")
else:
    print("Scrape Error")
# Out:
# Scrape Error

# %%
# The below code is only for reference
# finds each product from the store page
containers = soup.find("div", {"class": "restaurants-container"})

container = containers.find_all("li")

# name the output file to write to local disk
out_filename = "foodora.csv"
# header of csv file to be written
headers = "Restaurant,Rating \n"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # The below code is only for reference
#       2 # finds each product from the store page
# ----> 3 containers = soup.find("div", {"class": "restaurants-container"})
#       5 container = containers.find_all("li")
#       7 # name the output file to write to local disk
#
# NameError: name 'soup' is not defined

# %%
# opens file, and writes headers
f = open(out_filename, "w+")
f.write(headers)

# loops over each product and grabs attributes about
# each product
for con in container:

    anchors = con.find_all('span', {"class": "headline"})
    if anchors:

        rating = con.find("span", {"class" : "rating--label-primary cl-rating-tag-text f-label-small-font-size fw-label-small-font-weight lh-label-small-line-height"})
        
        title = con.find('a', {"class" : "name fn"})

        if rating is None:
            c = title.text
            b= None
        else:
            b = rating.text
            c = title.text

        # prints the dataset to console
        print(c)
        print(b)
        print(c, b, file=open(out_filename, "a"))


f.close()  # Close the file
# Out:
# The Italian Cousins Södermalm
# 4.2/5
# Sizzle Hemmakockar Stora Essingen
# None
# Jensens Bøfhus Stockholm
# 3.7/5
# Amazing Thai Restaurang
# 4/5
# Tehran Grill Rörstrandsgatan
# 4.6/5
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25700/3138890635.py in <module>
#      24         print(c)
#      25         print(b)
# ---> 26         print(c, b, file=open(out_filename, "a"))
#      27
#      28
#
# ~\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0308' in position 15: character maps to <undefined>
