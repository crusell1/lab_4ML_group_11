# %% [markdown]
# ## Labb 4, Grupp 11

# %% [markdown]
# ### Task 1

# %% [markdown]
# Chosen topic: Machine Learning
#
# Chosen websites: https://www.ibm.com/think/topics/machine-learning, https://mitsloan.mit.edu/ideas-made-to-matter/machine-learning-explained

# %%
# Importeringar
from bs4 import BeautifulSoup
import requests
import sys

# %% [markdown]
#  Hemsida 1

# %%
USER_AGENT = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"

headers = {"user-agent": USER_AGENT}
r = requests.get("https://www.ibm.com/think/topics/machine-learning", headers=headers)

print("Status code: ", r.status_code)
# Out:
# Status code:  200

# %%
if r.status_code == 200:
    print("Scrapping is possible")
    soup = BeautifulSoup(r.content, "html.parser")
else:
    print("Scrapping is not possible")
    sys.exit(0)
# Out:
# Scrapping is possible

# %%
# Benämde filen som texten ska lagras i
out_filename = "ibm.txt"

# Hittar titelns tagg, dvs h1
title_tag = soup.find("h1")
# Hämtar all text i titelns tagg och skalar den
# Om ingen titel tagg finns så returneras "Ingen Titel"
title = title_tag.get_text(strip=True) if title_tag else "No Title"

# Hittar div:en med klassen "body-article-8" som består av all text på sidan
content_div = soup.find("div", {"class": "body-article-8"})

# Om div:en med all text inte finns, skickas följande felmeddelande
if not content_div:
    print("Content not found. Website structure may have changed.")
    sys.exit(0)

# Hittar samtliga p- och li-taggar i div:en med all text
paragraphs = content_div.find_all(["p", "li"])

# Initierar variabeln som ska hålla all text
article_text = ""

# Loop för varje p-tagg
for p in paragraphs:
    # Hämtar texten från p-taggen och skalar den
    text = p.get_text(strip=True)
    # Om det finns text, lägg till den och en ny rad i variabeln som håller texten
    if text:
        article_text += text + "\n"

# Öppnar textfilen, väljer skrivläget och specificerar Unicode
with open(out_filename, "w", encoding="utf-8") as f:
    # Skriver in titeln och två nya rader
    f.write(title + "\n\n")
    # Skriver in all text från artikeln
    f.write(article_text)

# Skriver ut meddelande om att det sparats i textfilen
print(f"Content saved to {out_filename}")

# Stänger filen
f.close()
# Out:
# Content saved to ibm.txt

# %% [markdown]
# Hemsida 2

# %%
USER_AGENT = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"

headers = {"user-agent": USER_AGENT}
r = requests.get("https://mitsloan.mit.edu/ideas-made-to-matter/machine-learning-explained", headers=headers)

print("Status code: ", r.status_code)
# Out:
# Status code:  200

# %%
if r.status_code == 200:
    print("Scrapping is possible")
    soup = BeautifulSoup(r.content, "html.parser")
else:
    print("Scrapping is not possible")
    sys.exit(0)
# Out:
# Scrapping is possible

# %%
# Benämde filen som texten ska lagras i
out_filename = "mit.txt"

# Hittar titelns tagg, dvs h1
title_tag = soup.find("h1")
# Hämtar all text i titelns tagg och skalar den
# Om ingen titel tagg finns så returneras "Ingen Titel"
title = title_tag.get_text(strip=True) if title_tag else "No Title"

# Hittar div:en med klassen "article--body" som består av all text på sidan
content_div = soup.find("div", {"class": "article--body"})

# Om div:en med all text inte finns, skickas följande felmeddelande
if not content_div:
    print("Content not found. Website structure may have changed.")
    sys.exit(0)

# Hittar samtliga p- och li-taggar i div:en med all text
paragraphs = content_div.find_all(["p"])

# Initierar variabeln som ska hålla all text
article_text = ""

# Loop för varje p-tagg
for p in paragraphs:
    # Hämtar texten från p-taggen och skalar den
    text = p.get_text(strip=True)
    # Om det finns text, lägg till den och en ny rad i variabeln som håller texten
    if text:
        article_text += text + "\n"

# Öppnar textfilen, väljer skrivläget och specificerar Unicode
with open(out_filename, "w", encoding="utf-8") as f:
    # Skriver in titeln och två nya rader
    f.write(title + "\n\n")
    # Skriver in all text från artikeln
    f.write(article_text)

# Skriver ut meddelande om att det sparats i textfilen
print(f"Content saved to {out_filename}")

# Stänger filen
f.close()
# Out:
# Content saved to mit.txt

# %% [markdown]
# ### Task 2

# %% [markdown]
# Chosen e-commerce: Kicks, https://www.kicks.se/

# %%
# desktop user-agent
USER_AGENT = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"

headers = {"user-agent": USER_AGENT}
r = requests.get("https://www.kicks.se/parfym?search-query=parfym", headers=headers)

print("Status code: ", r.status_code)
# Out:
# Status code:  200

# %%
if r.status_code == 200:
    print("Scrapping is possible")
    soup = BeautifulSoup(r.content, "html.parser")
else:
    print("Scrapping is not possible")
    sys.exit(0)
# Out:
# Scrapping is possible

# %%
# The below code is only for reference
# finds each product from the store page
containers = soup.find("div", {"class": "ProductList__Grid-sc-1kxgi4x-0 gdBrrB"})

container = containers.find_all("div", {"class": "ProductItem__Wrapper-sc-1wmia3i-0 bQprsQ"})

# name the output file to write to local disk
out_filename = "kicks.csv"
# header of csv file to be written
headers = "Parfym,Pris \n"

# %%
# opens file, and writes headers
f = open(out_filename, "w+")
f.write(headers)

# loops over each product and grabs attributes about
# each product
for con in container:

    anchors = con.find_all('div', {"class": "CardContent__StyledCardContent-sc-15yb5cd-0 hjpqjg styles__ProductContent-sc-1hwmg7-1 dAXpFB"})
    if anchors:

        price = con.find("span", {"class" : "Text__TextElement-sc-1xtks91-0 ftSbqw Price__StyledText-sc-u0vxfc-1"})
        
        title = con.find('span', {"class" : "Body__StyledBody-sc-1bcfcvm-0 eHlofd styles__Product-sc-1ijnrjd-1 dIsTUL"})

        if price is None:
            c = title.text
            b = None
        else:
            c = title.text
            b = price.text

        # prints the dataset to console
        print(c)
        print(b)
        print(c, b, file=open(out_filename, "a"))

f.close()  # Close the file
# Out:
# Bal D'Afrique EdP
# 1 770 kr
# Gypsy Water EdP
# 1 770 kr
# Bal d'Afrique Absolu EdP
# 2 320 kr
# Le Male In Blue EdP Natural Spray
# 1 075 kr
# Night Veils Vanille Antique EdP
# 3 690 kr
# Blanche EdP
# 2 640 kr
# Lancôme La Vie est Belle Eau de Parfum
# 999 kr
# euphoria solar elixir Parfum Intense for Women
# 1 080 kr
# Bal D'Afrique Body Lotion
# 620 kr
# Young Rose EdP
# 1 770 kr
# Alto Astral EdP
# 1 770 kr
# Idôle Eau de Parfum
# 1 699 kr
# Le Male Le Parfum Intense
# 1 555 kr
# Lancôme La Vie est Belle Eau de Parfum
# None
# La Belle EdP
# 1 280 kr
# Fame Eau de parfum
# 910 kr
# Gaultier Divine Couture EdP Natural Spray
# 910 kr
# Miracle EdP
# 1 229 kr
# Rose Of No Man's Land Absolu EdP
# 3 180 kr
# Daisy Eau So Fresh EdT
# 1 630 kr
# Eternity For Women EdP
# 725 kr
# L'Interdit Parfum
# 1 600 kr
# Million Gold For Her EdP
# 1 435 kr
# Lancôme La Vie est Belle Eau de Parfum
# 1 499 kr
# Le Beau Le Parfum EdP
# 1 195 kr
# Gentleman Society EdP
# 1 290 kr
# Gaultier Divine Elixir Parfum
# 1 570 kr
# Million Gold For Her EdP 50 ml Gift Box
# 1 430 kr
# Le Beau Paradise Garden EdP
# 1 170 kr
# Digitalt Presentkort
# Min 50 kr
# Olympea Eau de parfum
# 1 225 kr
# Born in Roma Donna Eau de Parfum
# None
# Paradoxe EdP
# None
# Bal D'Afrique Hair Perfume
# 700 kr
# Le Male Eau de Toilette
# 795 kr
# Yves Saint Laurent Libre Eau de Parfum
# None
# Good Girl EdP
# None
# Bibliothèque Candle
# 820 kr
# La Vie Est Belle Hair And Body Mist
# 580 kr
# The Scent For Her EdP
# None
# Born In Roma Yellow Dream Uomo EdT
# 1 049 kr
# Oud Wood EdP
# 2 899 kr
# Dior Homme Intense EdP
# 1 689 kr
# Black Opium EdP
# None
# euphoria magnetic elixir Parfum Intense for Women
# 1 080 kr
# Papaya Paradise Hair & Body Perfume Mist
# 350 kr
# Dior Homme Parfum
# 1 789 kr
# Eilish EdP
# None
# Eros EdT
# None
# Paradoxe Intense EdP
# 1 689 kr
# Miss Dior Parfum
# 1 459 kr
# Hair & Body Mist Vanilla Dew
# 329 kr
# Devotion Pour Homme Parfum
# 1 295 kr
# Percival EdP
# 3 329 kr
# Y EdT
# 1 449 kr
# Light Blue EdT
# None
# Angels' Share EdP
# 3 299 kr
# Whipped Vanilla Hair & Body Perfume Mist
# 350 kr
# My Way EdP
# None
# VALENT Born In Roma Donna
# 400 kr
# Narcotic Delight EdP
# 2 529 kr
# Athénais EdP
# 3 270 kr
# Sauvage EdP
# 1 199 kr
# Erba Gold EdP
# 2 243 kr
# Cosmic Intense Eau de Parfum
# 620 kr
# Yum me Sunny EdP
# 610 kr
# The Ritual Of Yozakura - Medium Gift Set 2025
# 419 kr
# Born In Roma Coral Fantasy Uomo EdT
# 1 049 kr
# Terre D'Hermès After Shave Balm
# 879 kr
# Miss Dior EdP
# 989 kr
# Giorgio Armani Sì Eau de Parfum
# None
# Emporio Armani Stronger With You Eau de Toilette
# 999 kr
# Bright Crystal Eau de Toilette
# None
# Valaya Exclusif
# 3 499 kr
# Crystal Emerald EdP
# 1 175 kr
# Her EdP
# 1 985 kr
# I Want Choo EdP
# 755 kr
# Santal 33 EdP
# 1 069 kr
# Miss Dior Blooming Bouquet EdT
# 1 699 kr
# Naxos EdP
# 2 818 kr
# Goddess EdP
# 1 985 kr
# 1 Million Deodorant Stick
# 400 kr
# Red Hibiscus Cologne Intense
# 1 589 kr
# Yves Saint Laurent MYSLF Eau de Parfum
# 1 799 kr
# Sauvage Deodorant Stick
# 499 kr
# J'adore Parfum d'Eau Alcohol-Free
# 1 969 kr
# Arabians Tonka EdP
# 1 805 kr
# Lagerfeld Classic Deodorant Stick
# 305 kr
# One Million Parfum Perfume
# None
# Miss Dior Essence
# 1 749 kr
